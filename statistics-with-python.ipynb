# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
import statistics

# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
df = sns.load_dataset('tips')

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
np.mean(df['total_bill'])
# Out:
# 19.78594262295082

# %%
np.median(df['total_bill'])
# Out:
# 17.795

# %%
statistics.mode(df['total_bill'])
# Out:
# 13.42

# %%
sns.boxplot(df['total_bill'],orient = 'horizontal', x= df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.histplot(df['total_bill'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(df['total_bill'], fill = True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# kernal density 
sns.histplot(df['total_bill'], kde = True )
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# <strong>OBSERVATION:</strong>
# NOT Gaussian/Normal Distribution, somewhat skewwed to right

# %%
df2 = sns.load_dataset('iris')

# %%
df2.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
sns.histplot(df2['sepal_length'], kde = True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df2['sepal_width'], kde = True)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
# sns.countplot(df2['species'])

# %% [markdown]
# should lokk like this , but updated sns version requires categorical values to be converted to numerical
# ![image.png](attachment:67bf1a7f-9b24-4d47-8440-b1758d6a75ea.png)

# %%
sns.countplot(x = df2['species'], data = df2)
plt.title('Count-Plot')
plt.show()

# %%
np.percentile(df2['sepal_length'],[25,75])
# Out:
# array([5.1, 6.4])

# %% [markdown]
# # Finding Outliers

# %%
# creating a custom dataset

dataset= [11,10,12,14,12,15,14,13,15,102,12,14,17,19,107, 10,13,12,14,12,108,12,11,14,13,15,10,15,12,10,14,13,15,10]

# %%
sns.barplot(dataset)
# Out:
# <Axes: >

# %%
sns.histplot(data = dataset,binwidth = 2)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %% [markdown]
# ### using z-score

# %%
#finding outliers using z-score


def find_outliers(data):
    outliers = []
    th = 3 # for 3rd std region
    mean = np.mean(data)
    std = np.std(data)
    
    for i in data:
        zscore = (i-mean)/std
        if abs(zscore) >th:
            outliers.append(i)
    
    return outliers

# %%
find_outliers(dataset)
# Out:
# [102, 107, 108]

# %% [markdown]
# ### Using IQR

# %%
### finding outliers using IQR (inter-quartile-range) :
# sort the data
# calculate Q1 (0.25) i.e 25%  percentile
# calculate Q3 (0.75) i.e 75%  percentile
# IQR = Q3 - Q1 
# lower-boundary or lower-fence = Q1 - 1.5(IQR)
# upper-boundary or upper-fence = Q1 + 1.5(IQR)

# %%
data2 = sorted(dataset)
data2
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  13,
#  14,
#  14,
#  14,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  15,
#  15,
#  17,
#  19,
#  102,
#  107,
#  108]

# %%
Q1,Q3 = np.percentile(data2,[25,75]) 
Q1,Q3
# Out:
# (12.0, 15.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# 3.0

# %%
lower_fence = Q1 - 1.5*IQR
upper_fence = Q3 + 1.5*IQR
lower_fence,upper_fence
# Out:
# (7.5, 19.5)

# %%
outliers = []
for i in data2:
    if lower_fence < i < upper_fence:
        continue
    else:
        outliers.append(i)

outliers
# Out:
# [102, 107, 108]

# %%
outliers = []
for i in data2:
    if i<lower_fence or i > upper_fence:
        outliers.append(i)

outliers
# Out:
# [102, 107, 108]

# %% [markdown]
# ### Outliers using Box Plot

# %%
data3 = dataset.copy()
sns.boxplot(dataset, orient = 'horizontal',color = 'pink')
plt.title('Outliers using Box-Plot')
plt.show()
